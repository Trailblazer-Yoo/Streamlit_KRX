# %%
import pandas as pd
tp = pd.read_excel('./KODEX_KTOP_30_20220720.xls',header=3)[14:34].reset_index().drop('index',axis=1).reset_index()
tp.to_csv('./KTOP30_price.csv')

# %%
df1 = pd.read_csv('./data_20200601_20220630.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      516 non-null    object
#  1   거래회전율   516 non-null    float64
#  2   환율      516 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 12.2+ KB

# %%
df1.iloc[-20:,:]
# Out:
#              날짜     거래회전율        환율
# 496  2022-06-02  0.199243  0.436000
# 497  2022-06-03  0.000000  0.414667
# 498  2022-06-07  0.235203  0.431500
# 499  2022-06-08  0.103493  0.404833
# 500  2022-06-09  0.343772  0.407667
# 501  2022-06-10  0.256366  0.404000
# 502  2022-06-13  0.314264  0.390000
# 503  2022-06-14  0.330437  0.356667
# 504  2022-06-15  0.334566  0.350500
# 505  2022-06-16  0.299467  0.347833
# 506  2022-06-17  0.414573  0.359833
# 507  2022-06-20  0.364504  0.354167
# 508  2022-06-21  0.261184  0.347167
# 509  2022-06-22  0.315296  0.349000
# 510  2022-06-23  0.385323  0.340500
# 511  2022-06-24  0.288971  0.332167
# 512  2022-06-27  0.226428  0.334333
# 513  2022-06-28  0.139195  0.357333
# 514  2022-06-29  0.215933  0.358500
# 515  2022-06-30  0.282519  0.345167

# %%
df1 = df1.iloc[-20:,:]
df1 = df1.reset_index().drop('index',axis=1)
df1
# Out:
#             날짜     거래회전율        환율
# 0   2022-06-02  0.199243  0.436000
# 1   2022-06-03  0.000000  0.414667
# 2   2022-06-07  0.235203  0.431500
# 3   2022-06-08  0.103493  0.404833
# 4   2022-06-09  0.343772  0.407667
# 5   2022-06-10  0.256366  0.404000
# 6   2022-06-13  0.314264  0.390000
# 7   2022-06-14  0.330437  0.356667
# 8   2022-06-15  0.334566  0.350500
# 9   2022-06-16  0.299467  0.347833
# 10  2022-06-17  0.414573  0.359833
# 11  2022-06-20  0.364504  0.354167
# 12  2022-06-21  0.261184  0.347167
# 13  2022-06-22  0.315296  0.349000
# 14  2022-06-23  0.385323  0.340500
# 15  2022-06-24  0.288971  0.332167
# 16  2022-06-27  0.226428  0.334333
# 17  2022-06-28  0.139195  0.357333
# 18  2022-06-29  0.215933  0.358500
# 19  2022-06-30  0.282519  0.345167

# %%
df2 = pd.read_csv('2022-06_score.csv')

# %%
df2 = df2.merge(df1,on='날짜',how='outer')
df2
# Out:
#             날짜      score     거래회전율        환율
# 0   2022-06-01  38.918779       NaN       NaN
# 1   2022-06-02  28.718668  0.199243  0.436000
# 2   2022-06-03  32.634572  0.000000  0.414667
# 3   2022-06-04  40.270144       NaN       NaN
# 4   2022-06-05  37.634442       NaN       NaN
# 5   2022-06-06  40.367536       NaN       NaN
# 6   2022-06-07  35.700046  0.235203  0.431500
# 7   2022-06-08  35.611877  0.103493  0.404833
# 8   2022-06-09  36.226128  0.343772  0.407667
# 9   2022-06-10  38.819116  0.256366  0.404000
# 10  2022-06-11  34.043619       NaN       NaN
# 11  2022-06-12  34.362585       NaN       NaN
# 12  2022-06-13  41.632068  0.314264  0.390000
# 13  2022-06-14  40.893236  0.330437  0.356667
# 14  2022-06-15  41.002991  0.334566  0.350500
# 15  2022-06-16  38.104501  0.299467  0.347833
# 16  2022-06-17  40.945957  0.414573  0.359833
# 17  2022-06-18  37.848969       NaN       NaN
# 18  2022-06-19  36.900901       NaN       NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      30 non-null     object
#  1   score   30 non-null     float64
#  2   거래회전율   20 non-null     float64
#  3   환율      20 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.2+ KB

# %%
df2['거래회전율'] = [i*100 for i in df2['거래회전율']]
df2['환율'] = [i*100 for i in df2['환율']]

# %%
df2
# Out:
#             날짜      score      거래회전율         환율
# 0   2022-06-01  38.918779        NaN        NaN
# 1   2022-06-02  28.718668  19.924295  43.600000
# 2   2022-06-03  32.634572   0.000000  41.466667
# 3   2022-06-04  40.270144        NaN        NaN
# 4   2022-06-05  37.634442        NaN        NaN
# 5   2022-06-06  40.367536        NaN        NaN
# 6   2022-06-07  35.700046  23.520303  43.150000
# 7   2022-06-08  35.611877  10.349277  40.483333
# 8   2022-06-09  36.226128  34.377151  40.766667
# 9   2022-06-10  38.819116  25.636614  40.400000
# 10  2022-06-11  34.043619        NaN        NaN
# 11  2022-06-12  34.362585        NaN        NaN
# 12  2022-06-13  41.632068  31.426359  39.000000
# 13  2022-06-14  40.893236  33.043703  35.666667
# 14  2022-06-15  41.002991  33.456641  35.050000
# 15  2022-06-16  38.104501  29.946662  34.783333
# 16  2022-06-17  40.945957  41.457330  35.983333
# 17  2022-06-18  37.848969        NaN        NaN
# 18  2022-06-19  36.900901        NaN        NaN
# ...

# %%
df2['fg_score'] = df2.mean(axis=1,skipna=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16900\2033187678.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2['fg_score'] = df2.mean(axis=1,skipna=True)

# %%
df2.to_dict()
# Out:
# {'날짜': {0: '2022-06-01',
#   1: '2022-06-02',
#   2: '2022-06-03',
#   3: '2022-06-04',
#   4: '2022-06-05',
#   5: '2022-06-06',
#   6: '2022-06-07',
#   7: '2022-06-08',
#   8: '2022-06-09',
#   9: '2022-06-10',
#   10: '2022-06-11',
#   11: '2022-06-12',
#   12: '2022-06-13',
#   13: '2022-06-14',
#   14: '2022-06-15',
#   15: '2022-06-16',
#   16: '2022-06-17',
#   17: '2022-06-18',
#   18: '2022-06-19',
#   19: '2022-06-20',
#   20: '2022-06-21',
#   21: '2022-06-22',
#   22: '2022-06-23',
#   23: '2022-06-24',
#   24: '2022-06-25',
#   25: '2022-06-26',
#   26: '2022-06-27',
#   27: '2022-06-28',
#   28: '2022-06-29',
#   29: '2022-06-30'},
#  'score': {0: 38.918779274004685,
#   1: 28.71866800954939,
#   2: 32.634571561051004,
#   3: 40.270143599195706,
#   4: 37.63444193817878,
#   5: 40.36753586862576,
#   6: 35.70004618885097,
#   7: 35.6118772845953,
#   8: 36.226128205128205,
#   9: 38.81911604959832,
#   10: 34.043618619246864,
#   11: 34.362584779706275,
# ...

# %%
df2
# Out:
#             날짜      score      거래회전율         환율   fg_score
# 0   2022-06-01  38.918779        NaN        NaN  38.918779
# 1   2022-06-02  28.718668  19.924295  43.600000  30.747654
# 2   2022-06-03  32.634572   0.000000  41.466667  24.700413
# 3   2022-06-04  40.270144        NaN        NaN  40.270144
# 4   2022-06-05  37.634442        NaN        NaN  37.634442
# 5   2022-06-06  40.367536        NaN        NaN  40.367536
# 6   2022-06-07  35.700046  23.520303  43.150000  34.123450
# 7   2022-06-08  35.611877  10.349277  40.483333  28.814829
# 8   2022-06-09  36.226128  34.377151  40.766667  37.123315
# 9   2022-06-10  38.819116  25.636614  40.400000  34.951910
# 10  2022-06-11  34.043619        NaN        NaN  34.043619
# 11  2022-06-12  34.362585        NaN        NaN  34.362585
# 12  2022-06-13  41.632068  31.426359  39.000000  37.352809
# 13  2022-06-14  40.893236  33.043703  35.666667  36.534535
# 14  2022-06-15  41.002991  33.456641  35.050000  36.503211
# ...

# %%
df2['fg_score'].plot()
# Out:
# <AxesSubplot:>

# %%
from scipy.interpolate import UnivariateSpline
import numpy as np

# %%
x = np.array(range(30))
y =  np.array(df2['fg_score'])

spl = UnivariateSpline(x, y)

spl = UnivariateSpline(x, y)
xs = np.array(range(30))
plt.plot(xs, spl(xs), 'r', lw=1)

# %%
df2.to_csv('./final.csv')
